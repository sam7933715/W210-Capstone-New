# %%
# from pandas.io.json import json_normalize
import json
import pandas as pd


with open("user_based_final.json", "r") as read_file:
    data = json.load(read_file)

svd_df = pd.DataFrame(data['data'])

# %%
svd_df.head()
# Out:
#    index      Target_business_id   Target_city             business_id  \
# 0      0  ym2GsJkdeGZqNn_Rf9UC3Q     Brentwood  SyAYFxPBjuaHajx9iE7wLQ
# 1      1  ym2GsJkdeGZqNn_Rf9UC3Q     Brentwood  bji0nOYNgVWMZkN6LqsEJA
# 2      2  E6Qs5dCetaqZqHOnqVZ2Ng  Philadelphia  aQ2-kEwDra31zu0NCLpUsQ
# 3      3  E6Qs5dCetaqZqHOnqVZ2Ng  Philadelphia  IWbAT_jOGwJuDE-BAZ1Riw
# 4      4  S7tZmvSqrpH18cDE_fwVgA  Philadelphia  HhaL0aFNFXsxitfL4E7upQ
#
#                    name                    address              city  \
# 0  Saint Louis Galleria  1155 Saint Louis Galleria       Saint Louis
# 1                Macy's  1550 Saint Louis Galleria  Richmond Heights
# 2      Buffalo Exchange           1520 Chestnut St      Philadelphia
# 3             Chop Shop               513 South St      Philadelphia
# 4      Suburban Station               34 N 16th St      Philadelphia
#
#     latitude  longitude  stars  \
# 0  38.634959 -90.348097    3.5
# 1  38.633849 -90.348257    3.0
# ...

# %%
svd_df.groupby(['Target_city','city']).agg({'name':'count'}).sort_values(by=['name'], ascending = False)[0:20]
# Out:
#                                name
# Target_city    city
# Philadelphia   Philadelphia     674
# New Orleans    New Orleans      504
# Reno           Reno             226
# Tucson         Tucson           222
# Tampa          Tampa            187
# Indianapolis   Indianapolis     161
# Nashville      Nashville        148
# Saint Louis    Saint Louis      127
# Edmonton       Edmonton          93
# Reno           Sparks            39
# Sparks         Reno              39
# Philadelphia   Media             30
# Kenner         New Orleans       28
# Philadelphia   Doylestown        26
#                Kennett Square    23
# Kennett Square Philadelphia      23
# Philadelphia   Glen Mills        19
# Media          Philadelphia      19
# Philadelphia   Aston             17
# Aston          Philadelphia      16

# %%
non_food_reviews = pd.read_csv("../yelp_dataset/non_food_merged.csv")

# %%
non_food_reviews.head()
# Out:
#    Unnamed: 0             business_id             name  \
# 0           0  n_0UpQx1hsNbnPUSlodU8w  Famous Footwear
# 1           1  n_0UpQx1hsNbnPUSlodU8w  Famous Footwear
# 2           2  n_0UpQx1hsNbnPUSlodU8w  Famous Footwear
# 3           3  n_0UpQx1hsNbnPUSlodU8w  Famous Footwear
# 4           4  n_0UpQx1hsNbnPUSlodU8w  Famous Footwear
#
#                                       address       city state postal_code  \
# 0  8522 Eager Road, Dierbergs Brentwood Point  Brentwood    MO       63144
# 1  8522 Eager Road, Dierbergs Brentwood Point  Brentwood    MO       63144
# 2  8522 Eager Road, Dierbergs Brentwood Point  Brentwood    MO       63144
# 3  8522 Eager Road, Dierbergs Brentwood Point  Brentwood    MO       63144
# 4  8522 Eager Road, Dierbergs Brentwood Point  Brentwood    MO       63144
#
#     latitude  longitude  stars_x  ...  \
# 0  38.627695 -90.340465      2.5  ...
# 1  38.627695 -90.340465      2.5  ...
# 2  38.627695 -90.340465      2.5  ...
# ...

# %%
non_food_reviews.columns
# Out:
# Index(['Unnamed: 0', 'business_id', 'name', 'address', 'city', 'state',
#        'postal_code', 'latitude', 'longitude', 'stars_x', 'review_count',
#        'is_open', 'attributes', 'categories', 'hours',
#        'BusinessAcceptsCreditCards', 'WheelchairAccessible', 'BusinessParking',
#        'ByAppointmentOnly', 'review_id', 'user_id', 'stars_y', 'useful',
#        'funny', 'cool', 'text', 'date'],
#       dtype='object')

# %%
non_food_reviews.categories[0]
# Out:
# 'Sporting Goods, Fashion, Shoe Stores, Shopping, Sports Wear, Accessories'
