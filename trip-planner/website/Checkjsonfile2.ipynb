# %%
# from pandas.io.json import json_normalize
import json
import pandas as pd


with open("user_based_final Arriana.json", "r") as read_file:
    data = json.load(read_file)

print(type(data))
svd_df = pd.DataFrame(data['data'])
svd_df.head()
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       7     data = json.load(read_file)
#       9 print(type(data))
# ---> 10 svd_df = pd.DataFrame(data['data'])
#      11 svd_df.head()
#
# TypeError: string indices must be integers

# %%
# from pandas.io.json import json_normalize
import json
import pandas as pd


with open("user_based_final Bruce.json", "r") as read_file:
    data2 = json.load(read_file)

print(type(data2))
svd_df_2 = pd.DataFrame(data2['data'])
svd_df_2.head()
# Out:
# <class 'dict'>
#    index      Target_business_id   Target_city             business_id  \
# 0      0  AfassS1QI0DHsqwuof9-lA  Philadelphia  nQTJn9kdpU9Mns-b_qduVw
# 1      1  AfassS1QI0DHsqwuof9-lA  Philadelphia  iH9fT2RCB0u4cVl2HLDtqg
# 2      2  AfassS1QI0DHsqwuof9-lA  Philadelphia  qdiuVbeHgis5LOgDJMBfcw
# 3      3  AfassS1QI0DHsqwuof9-lA  Philadelphia  jcmJVfvefkVnx6h_idOazA
# 4      4  AfassS1QI0DHsqwuof9-lA  Philadelphia  2YyIIdwnYv5cApn1gZo_gw
#
#                name            address          city   latitude  longitude  \
# 0       The Barbary  951 Frankford Ave  Philadelphia  39.965554 -75.134220
# 1  The Franklin Bar      112 S 18th St  Philadelphia  39.951299 -75.170647
# 2   12th Street Gym      204 S 12th St  Philadelphia  39.948204 -75.160744
# 3  Connie's Ric Rac      1132 S 9th St  Philadelphia  39.935522 -75.158719
# 4       Field House    1150 Filbert St  Philadelphia  39.952616 -75.159445
#
#    stars                                                Map  \
# 0    4.0  https://www.google.com/maps/search/?api=1&quer...
# 1    4.0  https://www.google.com/maps/search/?api=1&quer...
# 2    4.0  https://www.google.com/maps/search/?api=1&quer...
# 3    3.5  https://www.google.com/maps/search/?api=1&quer...
# 4    2.5  https://www.google.com/maps/search/?api=1&quer...
#
#                                                photo  \
# 0  http://tse2.mm.bing.net/th/id/OIP.I65SWIbWnn5F...
# 1  http://tse1.mm.bing.net/th/id/OIP.eXfI8hWG4UjY...
# 2  http://tse1.mm.bing.net/th/id/OIP.o2KXXCxImMOQ...
# 3  http://tse4.mm.bing.net/th/id/OIP.cvtwebozVT_m...
# 4  http://tse3.mm.bing.net/th/id/OIP.gxh8rdyXX0jK...
#
#                                      Target_category  \
# 0  Arts & Entertainment, Bars, Jazz & Blues, Dive...
# 1  Arts & Entertainment, Bars, Jazz & Blues, Dive...
# 2  Arts & Entertainment, Bars, Jazz & Blues, Dive...
# 3  Arts & Entertainment, Bars, Jazz & Blues, Dive...
# 4  Arts & Entertainment, Bars, Jazz & Blues, Dive...
#
#                                             category Rec_final_score  \
# 0  Arts & Entertainment, Dance Clubs, Music Venue...               ?
# 1            Cocktail Bars, Nightlife, Lounges, Bars               ?
# 2  Gyms, Active Life, Trainers, Fitness & Instruc...               ?
# 3  Music Venues, Nightlife, Arts & Entertainment,...               ?
# 4                       Bars, Sports Bars, Nightlife               ?
#
#   Rec_final_rank  Rec_user_score  Rec_user_rank Rec_content_score
# 0              ?             4.1              1                 ?
# 1              ?             4.2              2                 ?
# 2              ?             4.1              3                 ?
# 3              ?             3.7              4                 ?
# 4              ?             2.8              5                 ?
