# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import json

# business=pd.read_json("yelp_dataset/yelp_academic_dataset_business.json", lines=True)
reviews=pd.read_json("yelp_dataset/yelp_academic_dataset_review.json", lines=True)

# %% [markdown]
# <a id="data"></a>
# # Data
#
# We are using subsets of each table since we have a large dataset to work with. For this notebook, we used _business_ and _review_ tables.

# %%
# peak the tables
display(business.head(2))
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
#
#                                attributes  \
# 0           {'ByAppointmentOnly': 'True'}
# 1  {'BusinessAcceptsCreditCards': 'True'}
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
#
#                                                hours
# 0                                               None
# ...

# %%
display(reviews.head(2))
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
#
#    stars  useful  funny  cool  \
# 0      3       0      0     0
# 1      5       1      0     1
#
#                                                 text                date
# 0  If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year... 2012-01-03 15:28:18

# %%
# Manually filter out non-travel related categories
non_restaurant = business[business['categories'].str.contains('Food|Medicine|Law|Specialist|Home|ologist|Health|Bank|Supplies|Dentist|Car|Recycling|Repair|Bail|Services') == False]
non_restaurant
# Out:
#                    business_id                        name  \
# 6       n_0UpQx1hsNbnPUSlodU8w             Famous Footwear
# 7       qkRM_2X51Yqxk3btlwAQIg              Temple Beth-El
# 10      UJsufbvfyfONHeWdvAHKjA                   Marshalls
# 17      M0XSSHqrASOnhgbWDJIpQA              Herb Import Co
# 21      qhDdDeI3K4jy2KyzwFN53w  Barnes & Noble Booksellers
# ...                        ...                         ...
# 150330  GeEveoOaU2YKD7jJtEfA_g             DeVons Jewelers
# 150341  IUQopTMmYQG-qRtBk-8QnA                Binh's Nails
# 150343  _QAMST-NrQobXduilWEqSw           Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw    Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                     Sic Ink
#
#                                            address            city state  \
# 6       8522 Eager Road, Dierbergs Brentwood Point       Brentwood    MO
# 7                               400 Pasadena Ave S  St. Petersburg    FL
# ...

# %%
cat = non_restaurant['categories']
unique_cat = set()
for item in cat:
    expanded = item.split(",")
    print(expanded)
    for i in expanded:
        i = i.strip()
        unique_cat.add(i)
# Out:
# ['Sporting Goods', ' Fashion', ' Shoe Stores', ' Shopping', ' Sports Wear', ' Accessories']
# ['Synagogues', ' Religious Organizations']
# ['Department Stores', ' Shopping', ' Fashion']
# ['Vape Shops', ' Tobacco Shops', ' Personal Shopping', ' Vitamins & Supplements', ' Shopping']
# ['Shopping', ' Books', ' Mags', ' Music & Video', ' Bookstores']
# ["Women's Clothing", ' Accessories', " Children's Clothing", " Men's Clothing", ' Adult', ' Shopping', ' Fashion']
# ['Trampoline Parks', ' Active Life']
# ['Dance Wear', ' Sports Wear', " Children's Clothing", ' Arts & Entertainment', ' Social Clubs', ' Performing Arts', ' Sporting Goods', ' Shoe Stores', ' Fashion', ' Shopping']
# ['Museums', ' Kids Activities', ' Arts & Entertainment', ' Education', ' Active Life', ' Playgrounds', " Children's Museums"]
# ['Hair Salons', ' Hair Extensions', ' Beauty & Spas', ' Wigs', ' Shopping']
# ['Active Life', ' Fitness & Instruction', ' Trainers', ' Gyms', ' Yoga']
# ['Uniforms', ' Shopping']
# ...

# %%
unique_cat = list(unique_cat)
print(len(unique_cat))
# Out:
# 459

# %%
unique_cat
# Out:
# ['Bike Parking',
#  'Trade Fairs',
#  'Diving',
#  'Jazz & Blues',
#  'Nail Salons',
#  'Parks',
#  'Flea Markets',
#  'Computers',
#  'Race Tracks',
#  'Public Markets',
#  'Gyms',
#  'Hot Air Balloons',
#  'Vinyl Records',
#  'Limos',
#  'High Fidelity Audio Equipment',
#  'Spray Tanning',
#  'Fuel Docks',
#  'Art Tours',
#  'Ceremonial Clothing',
#  'Tiki Bars',
#  'Bicycle Paths',
#  'Performing Arts',
#  'Pop-up Shops',
#  'Meditation Centers',
#  'Aerial Tours',
#  'Diamond Buyers',
#  'Local Flavor',
#  'Auto Upholstery',
#  'Fur Clothing',
#  'Whale Watching Tours',
#  'Comic Books',
#  'Bicycles',
#  'Axe Throwing',
#  'Body Shops',
#  'Piercing',
#  'RV Parks',
#  'Bookstores',
#  'Hiking',
#  'Vacation Rental Agents',
#  'Haunted Houses',
#  'Tattoo',
#  'Pilates',
#  'Truck Rental',
#  'Zoos',
#  'First Aid Classes',
#  'Rodeo',
#  'Watches',
#  'Laser Hair Removal',
#  'Bikes',
#  'Day Camps',
#  'Surf Shop',
#  'Cinema',
#  'Pets',
#  'Safety Equipment',
# ...

# %%
non_food = non_restaurant

# %%
non_food
# Out:
#                    business_id                        name  \
# 6       n_0UpQx1hsNbnPUSlodU8w             Famous Footwear
# 7       qkRM_2X51Yqxk3btlwAQIg              Temple Beth-El
# 10      UJsufbvfyfONHeWdvAHKjA                   Marshalls
# 17      M0XSSHqrASOnhgbWDJIpQA              Herb Import Co
# 21      qhDdDeI3K4jy2KyzwFN53w  Barnes & Noble Booksellers
# ...                        ...                         ...
# 150330  GeEveoOaU2YKD7jJtEfA_g             DeVons Jewelers
# 150341  IUQopTMmYQG-qRtBk-8QnA                Binh's Nails
# 150343  _QAMST-NrQobXduilWEqSw           Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw    Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                     Sic Ink
#
#                                            address            city state  \
# 6       8522 Eager Road, Dierbergs Brentwood Point       Brentwood    MO
# 7                               400 Pasadena Ave S  St. Petersburg    FL
# ...

# %%
result = pd.concat([non_food, reviews], axis =1)

# %%
result.head()
# Out:
#   business_id name address city state postal_code  latitude  longitude stars  \
# 0         NaN  NaN     NaN  NaN   NaN         NaN       NaN        NaN   NaN
# 1         NaN  NaN     NaN  NaN   NaN         NaN       NaN        NaN   NaN
# 2         NaN  NaN     NaN  NaN   NaN         NaN       NaN        NaN   NaN
# 3         NaN  NaN     NaN  NaN   NaN         NaN       NaN        NaN   NaN
# 4         NaN  NaN     NaN  NaN   NaN         NaN       NaN        NaN   NaN
#
#    review_count  ...  ByAppointmentOnly               review_id  \
# 0           NaN  ...                NaN  KU_O5udG6zpxOg-VcAEodg
# 1           NaN  ...                NaN  BiTunyQ73aT9WBnpR9DZGw
# 2           NaN  ...                NaN  saUsX_uimxRlCVr67Z4Jig
# 3           NaN  ...                NaN  AqPFMleE6RsU23_auESxiA
# 4           NaN  ...                NaN  Sx8TMOWLNuJBWer-0pcmoA
#
#                   user_id             business_id stars useful funny cool  \
# ...

# %%
reviews.head(2)
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
#
#    stars  useful  funny  cool  \
# 0      3       0      0     0
# 1      5       1      0     1
#
#                                                 text                date
# 0  If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year... 2012-01-03 15:28:18

# %%
non_food
# Out:
#                    business_id                        name  \
# 6       n_0UpQx1hsNbnPUSlodU8w             Famous Footwear
# 7       qkRM_2X51Yqxk3btlwAQIg              Temple Beth-El
# 10      UJsufbvfyfONHeWdvAHKjA                   Marshalls
# 17      M0XSSHqrASOnhgbWDJIpQA              Herb Import Co
# 21      qhDdDeI3K4jy2KyzwFN53w  Barnes & Noble Booksellers
# ...                        ...                         ...
# 150330  GeEveoOaU2YKD7jJtEfA_g             DeVons Jewelers
# 150341  IUQopTMmYQG-qRtBk-8QnA                Binh's Nails
# 150343  _QAMST-NrQobXduilWEqSw           Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw    Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                     Sic Ink
#
#                                            address            city state  \
# 6       8522 Eager Road, Dierbergs Brentwood Point       Brentwood    MO
# 7                               400 Pasadena Ave S  St. Petersburg    FL
# ...
